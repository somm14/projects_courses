# %% [markdown]
# ### IMPORTACIÓN DE LIBRERÍAS

# %%
import os
os.chdir("..")

# %%
from utils.funciones import *
from utils.modulos import *

# %% [markdown]
# ### OBTENCIÓN DE DATOS Y LIMPIEZA DE LOS MISMOS
#
# Comienzo con los datos socioeconómicos del año **2014**

# %%
df_economia_2014 = pd.read_excel("./data/socio_economico/panel_indicadores_distritos_barrios_2018.xls", sheet_name="CENTRO")

# %%
df_economia_2014 #Visualizo como se ve el DF
# Out:
#          01. CENTRO. INFORMACIÓN DE DISTRITO Y BARRIOS Unnamed: 1 Unnamed: 2  \
# 0                                                          CIUDAD        NaN
# 1    1.1 CARACTERÍSTICAS GENERALES DEL DISTRITO-BARRIO        NaN        NaN
# 2                                    Superficie (Ha.)         NaN   60445.51
# 3                                 Densidad (hab./Ha.)         NaN      52.65
# 4                       1.2. LA POBLACIÓN DEL DISTRITO        NaN        NaN
# ..                                                 ...        ...        ...
# 365       920.01 DIREC. Y GESTIÓN ADMTVA. DEL DISTRITO        NaN    4663405
# 366      924.01 PARTICIPACIÓN CIUDADANA Y VOLUNTARIADO        NaN        NaN
# 367                                  933.02 EDIFICIOS         NaN        NaN
# 368                                         CENTRO 001        NaN   18801730
# 369                                        SECCIÓN 201        NaN   18801730
#
# ...

# %%
renta_centro_2014 = df_economia_2014.iloc[48,4] # Como he estado ingestigando en el excel original para buscar el dato, lo localizo y lo guardo en una variable

# %%
renta_centro_2014
# Out:
# 30197.43913377805

# %%
# Creo un DF para buscar los datos de todos lo distritos
renta_arganzuela_2014 = 0.0
renta_arganzuela_2014 = dato_renta_2014(renta_arganzuela_2014, "ARGANZUELA")

# %%
renta_arganzuela_2014
# Out:
# 38308.48059128802

# %%
renta_retiro_2014 = 0.0
renta_retiro_2014 = dato_renta_2014(renta_retiro_2014, "RETIRO")

renta_salamanca_2014 = 0.0
renta_salamanca_2014 = dato_renta_2014(renta_salamanca_2014, "SALAMANCA")

renta_chamartin_2014 = 0.0
renta_chamartin_2014 = dato_renta_2014(renta_chamartin_2014, "CHAMARTÍN")

renta_tetuan_2014 = 0.0
renta_tetuan_2014 = dato_renta_2014(renta_tetuan_2014, "TETUÁN")

renta_chamberi_2014 = 0.0
renta_chamberi_2014 = dato_renta_2014(renta_chamberi_2014, "CHAMBERÍ")

renta_fuencarral_2014 = 0.0
renta_fuencarral_2014 = dato_renta_2014(renta_fuencarral_2014, "FUENCARRAL-EL PARDO")

renta_moncloa_2014 = 0.0
renta_moncloa_2014 = dato_renta_2014(renta_moncloa_2014, "MONCLOA-ARAVACA")

renta_latina_2014 = 0.0
renta_latina_2014 = dato_renta_2014(renta_latina_2014, "LATINA")

renta_carabanchel_2014 = 0.0
renta_carabanchel_2014 = dato_renta_2014(renta_carabanchel_2014, "CARABANCHEL")

renta_usera_2014 = 0.0
renta_usera_2014 = dato_renta_2014(renta_usera_2014, "USERA")

renta_puente_vallecas_2014 = 0.0
renta_puente_vallecas_2014 = dato_renta_2014(renta_puente_vallecas_2014, "PUENTE DE VALLECAS")

renta_moratalaz_2014 = 0.0
renta_moratalaz_2014  = dato_renta_2014(renta_moratalaz_2014, "MORATALAZ")

renta_ciudad_lineal_2014 = 0.0
renta_ciudad_lineal_2014 = dato_renta_2014(renta_ciudad_lineal_2014, "CIUDAD LINEAL")

renta_hortaleza_2014 = 0.0
renta_hortaleza_2014 = dato_renta_2014(renta_hortaleza_2014, "HORTALEZA")

renta_villaverde_2014 = 0.0
renta_villaverde_2014 = dato_renta_2014(renta_villaverde_2014, "VILLAVERDE")

renta_villa_vallecas_2014 = 0.0
renta_villa_vallecas_2014 = dato_renta_2014(renta_villa_vallecas_2014, "VILLA DE VALLECAS")

renta_vicalvaro_2014 = 0.0
renta_vicalvaro_2014 = dato_renta_2014(renta_vicalvaro_2014, "VICÁLVARO")

renta_sanblas_2014 = 0.0
renta_sanblas_2014 = dato_renta_2014(renta_sanblas_2014, "SAN BLAS-CANILLEJAS")

renta_barajas_2014 = 0.0
renta_barajas_2014 = dato_renta_2014(renta_barajas_2014, "BARAJAS")

# %%
# Hago lo mismo para el año 2020

df_economia_2020 = pd.read_excel("./data/socio_economico/panel_indicadores_distritos_barrios_2023.xlsx", sheet_name="CENTRO")

# %%
df_economia_2020
# Out:
#      Unnamed: 0       1. CENTRO. INFORMACIÓN DE DISTRITO Y BARRIOS Unnamed: 2  \
# 0           NaN                                                        CIUDAD
# 1           NaN  1.1 CARACTERÍSTICAS GENERALES DEL DISTRITO-BARRIO        NaN
# 2           NaN                                  Superficie (Ha.)    60445.52
# 3           NaN                               Densidad (hab./Ha.)   55.255228
# 4           NaN                     1.2. LA POBLACIÓN DEL DISTRITO        NaN
# ..          ...                                                ...        ...
# 378         NaN                            PARTICIPACIÓN CIUDADANA     924.01
# 379         NaN                                 SALUBRIDAD PÚBLICA     311.01
# 380         NaN                SERVICIOS COMPLEMENTARIOS EDUCACIÓN     326.01
# 381         NaN             SERVICIOS SOCIALES Y EMERGENCIA SOCIAL     231.06
# 382         NaN                                        SECCIÓN 201        NaN
#
# ...

# %%
renta_centro_2020 = df_economia_2020.iloc[53,5]

# %%
renta_centro_2020
# Out:
# 36984.0

# %%
renta_arganzuela_2020 = 0.0
renta_arganzuela_2020 = dato_renta_2020(renta_arganzuela_2020, "ARGANZUELA")

renta_retiro_2020 = 0.0
renta_retiro_2020 = dato_renta_2020(renta_retiro_2020, "RETIRO")

renta_salamanca_2020 = 0.0
renta_salamanca_2020 = dato_renta_2020(renta_salamanca_2020, "SALAMANCA")

renta_chamartin_2020 = 0.0
renta_chamartin_2020 = dato_renta_2020(renta_chamartin_2020, "CHAMARTÍN")

renta_tetuan_2020 = 0.0
renta_tetuan_2020 = dato_renta_2020(renta_tetuan_2020, "TETUÁN")

renta_chamberi_2020 = 0.0
renta_chamberi_2020 = dato_renta_2020(renta_chamberi_2020, "CHAMBERÍ")

renta_fuencarral_2020 = 0.0
renta_fuencarral_2020 = dato_renta_2020(renta_fuencarral_2020, "FUENCARRAL-EL PARDO")

renta_moncloa_2020 = 0.0
renta_moncloa_2020 = dato_renta_2020(renta_moncloa_2020, "MONCLOA-ARAVACA")

renta_latina_2020 = 0.0
renta_latina_2020 = dato_renta_2020(renta_latina_2020, "LATINA")

renta_carabanchel_2020 = 0.0
renta_carabanchel_2020 = dato_renta_2020(renta_carabanchel_2020, "CARABANCHEL")

renta_usera_2020 = 0.0
renta_usera_2020 = dato_renta_2020(renta_usera_2020, "USERA")

renta_puente_vallecas_2020 = 0.0
renta_puente_vallecas_2020 = dato_renta_2020(renta_puente_vallecas_2020, "PUENTE DE VALLECAS")

renta_moratalaz_2020 = 0.0
renta_moratalaz_2020  = dato_renta_2020(renta_moratalaz_2020, "MORATALAZ")

renta_ciudad_lineal_2020= 0.0
renta_ciudad_lineal_2020 = dato_renta_2020(renta_ciudad_lineal_2020, "CIUDAD LINEAL")

renta_hortaleza_2020 = 0.0
renta_hortaleza_2020 = dato_renta_2020(renta_hortaleza_2020, "HORTALEZA")

renta_villaverde_2020 = 0.0
renta_villaverde_2020 = dato_renta_2020(renta_villaverde_2020, "VILLAVERDE")

renta_villa_vallecas_2020 = 0.0
renta_villa_vallecas_2020 = dato_renta_2020(renta_villa_vallecas_2020, "VILLA DE VALLECAS")

renta_vicalvaro_2020 = 0.0
renta_vicalvaro_2020 = dato_renta_2020(renta_vicalvaro_2020, "VICÁLVARO")

renta_sanblas_2020 = 0.0
renta_sanblas_2020 = dato_renta_2020(renta_sanblas_2020, "SAN BLAS-CANILLEJAS")

renta_barajas_2020 = 0.0
renta_barajas_2020 = dato_renta_2020(renta_barajas_2020, "BARAJAS")

# %%
# Lo junto todo en un DF

distritos = "Centro", "Arganzuela", "Retiro", "Salamanca", "Chamartín", "Tetuán",\
    "Chamberí", "Fuencarral-El Pardo", "Moncloa-Aravaca","Latina", "Carabanchel",\
        "Usera", "Puente de Vallecas", "Moratalaz", "Ciudad Lineal", "Hortaleza",\
             "Villaverde", "Villa de Vallecas", "Vicálvaro", "San Blas", "Barajas"

renta_2014 = [
    renta_centro_2014, renta_arganzuela_2014, renta_retiro_2014, renta_salamanca_2014,
    renta_chamartin_2014, renta_tetuan_2014, renta_chamberi_2014, renta_fuencarral_2014,
    renta_moncloa_2014, renta_latina_2014, renta_carabanchel_2014, renta_usera_2014,
    renta_puente_vallecas_2014, renta_moratalaz_2014, renta_ciudad_lineal_2014,
    renta_hortaleza_2014, renta_villaverde_2014, renta_villa_vallecas_2014,
    renta_vicalvaro_2014, renta_sanblas_2014, renta_barajas_2014
    ]

# %%
df_renta_2014 = pd.DataFrame({
    "Año": [2014] * len(distritos),
    "Distrito": distritos,
    "Renta": renta_2014
})

# %%
df_renta_2014
# Out:
#      Año             Distrito         Renta
# 0   2014               Centro  30197.439134
# 1   2014           Arganzuela  38308.480591
# 2   2014               Retiro  54250.433710
# 3   2014            Salamanca  57371.989198
# 4   2014            Chamartín  65216.040487
# 5   2014               Tetuán  32624.345565
# 6   2014             Chamberí  49347.596364
# 7   2014  Fuencarral-El Pardo  54478.579918
# 8   2014      Moncloa-Aravaca  69915.639942
# 9   2014               Latina  29817.659455
# 10  2014          Carabanchel  26625.880759
# 11  2014                Usera  24059.927613
# 12  2014   Puente de Vallecas  23405.032090
# 13  2014            Moratalaz  34191.247598
# 14  2014        Ciudad Lineal  44001.479285
# 15  2014            Hortaleza  56606.329441
# 16  2014           Villaverde  24870.778166
# 17  2014    Villa de Vallecas  31063.398663
# 18  2014            Vicálvaro  27926.540251
# 19  2014             San Blas  32807.055664
# ...

# %%
renta_2020 = [
    renta_centro_2020, renta_arganzuela_2020, renta_retiro_2020, renta_salamanca_2020,
    renta_chamartin_2020, renta_tetuan_2020, renta_chamberi_2020, renta_fuencarral_2020,
    renta_moncloa_2020, renta_latina_2020, renta_carabanchel_2020, renta_usera_2020,
    renta_puente_vallecas_2020, renta_moratalaz_2020, renta_ciudad_lineal_2020,
    renta_hortaleza_2020, renta_villaverde_2020, renta_villa_vallecas_2020,
    renta_vicalvaro_2020, renta_sanblas_2020, renta_barajas_2020
    ]

# %%
df_renta_2020 = pd.DataFrame({
    "Año": [2020] * len(distritos),
    "Distrito": distritos,
    "Renta": renta_2020
})

# %%
df_renta_2020
# Out:
#      Año             Distrito    Renta
# 0   2020               Centro  36984.0
# 1   2020           Arganzuela  45310.0
# 2   2020               Retiro  56302.0
# 3   2020            Salamanca  60401.0
# 4   2020            Chamartín  69202.0
# 5   2020               Tetuán  38799.0
# 6   2020             Chamberí  55757.0
# 7   2020  Fuencarral-El Pardo  54292.0
# 8   2020      Moncloa-Aravaca  62202.0
# 9   2020               Latina  32957.0
# 10  2020          Carabanchel  30890.0
# 11  2020                Usera  28770.0
# 12  2020   Puente de Vallecas  27714.0
# 13  2020            Moratalaz  37890.0
# 14  2020        Ciudad Lineal  40532.0
# 15  2020            Hortaleza  52880.0
# 16  2020           Villaverde  29640.0
# 17  2020    Villa de Vallecas  34190.0
# 18  2020            Vicálvaro  35589.0
# 19  2020             San Blas  38163.0
# 20  2020              Barajas  50985.0

# %%
df_renta = pd.concat([df_renta_2014, df_renta_2020])

# %%
df_renta
# Out:
#      Año             Distrito         Renta
# 0   2014               Centro  30197.439134
# 1   2014           Arganzuela  38308.480591
# 2   2014               Retiro  54250.433710
# 3   2014            Salamanca  57371.989198
# 4   2014            Chamartín  65216.040487
# 5   2014               Tetuán  32624.345565
# 6   2014             Chamberí  49347.596364
# 7   2014  Fuencarral-El Pardo  54478.579918
# 8   2014      Moncloa-Aravaca  69915.639942
# 9   2014               Latina  29817.659455
# 10  2014          Carabanchel  26625.880759
# 11  2014                Usera  24059.927613
# 12  2014   Puente de Vallecas  23405.032090
# 13  2014            Moratalaz  34191.247598
# 14  2014        Ciudad Lineal  44001.479285
# 15  2014            Hortaleza  56606.329441
# 16  2014           Villaverde  24870.778166
# 17  2014    Villa de Vallecas  31063.398663
# 18  2014            Vicálvaro  27926.540251
# 19  2014             San Blas  32807.055664
# ...

# %%
# Lo guardo en un archivo JSON

df_renta.to_json("df_renta.json", orient="records", lines=True, force_ascii=False)
