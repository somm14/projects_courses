# %% [markdown]
# # Categorización y mapeo de los datos
# _____________

# %%
# Cambio el currenty directory ya que estoy dentro de notebooks y me quiero importar los modulos que estan dentro de 'utils'
import os
os.chdir('..') # Modifico a una carpeta hacia atras
os.listdir() # Compruebo viendo que estan las carpetas dentro de src
# Out:
# ['data', 'memoria.ipynb', 'notebooks', 'utils']

# %% [markdown]
# ## Importaciones

# %%
# Importacion de utils
from utils.funcions import *
from utils.modulos import *
import utils.toolbox_ML as tb
import utils.bootcampviztools as bt

# %% [markdown]
# ## Carga de datos

# %%
print("Ruta actual:", os.getcwd())
os.listdir()
os.chdir('src')
os.listdir()
# Out:
# Ruta actual: c:\Users\sorim\BOOTCAMP_EJERCICIOS\Proyectos\ML_final
# ['data', 'memoria.ipynb', 'notebooks', 'utils']

# %%
# Descomprimo el archivo .zip como hemos aprendido
path_to_zip_file = './data/raw/archive.zip'
directory = './data/raw/'

with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory)

# %%
df = pd.read_csv('./data/raw/dataset.csv')

# %% [markdown]
# ## Primera visualización de los datos

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
tb.describe_df(df)
# Out:
#            COL_N Marital status Application mode Application order Course  \
# 0      DATA_TYPE          int64            int64             int64  int64
# 1   MISSINGS (%)            0.0              0.0               0.0    0.0
# 2  UNIQUE_VALUES              6               18                 8     17
# 3     CARDIN (%)           0.14             0.41              0.18   0.38
#
#   Daytime/evening attendance Previous qualification Nacionality  \
# 0                      int64                  int64       int64
# 1                        0.0                    0.0         0.0
# 2                          2                     17          21
# 3                       0.05                   0.38        0.47
#
#   Mother's qualification Father's qualification  ...  \
# 0                  int64                  int64  ...
# 1                    0.0                    0.0  ...
# 2                     29                     34  ...
# 3                   0.66                   0.77  ...
#
# ...

# %% [markdown]
# - No hay valores nulos, a simple vista.
# - Todas las variables son de tipo numérica, indispensable a la hora de aplicar los algoritmos. Sin embargo, hay variables que no podemos llegar a comprender el significado de esos valores ya que esos datos numéricos no tienen un orden lógico si se interpretara como datos de tipo texto.
# - En cambio, la única variable que es de tipo `object` es nuestra columna objetivo.

# %% [markdown]
# ## Investigación de los datos
#
# Como he mencionado anteriormente, todas las variables tienen un contenido numérico, exceptuando nuestro **Target**.
#
# Voy a hacer un análisis de cada variable según si son categóricas, numéricas dicretas o continuas.

# %%
# Tipifico las variables
categorizacion = tb.tipifica_variables(df, 22, 20.1)
categorizacion
# Out:
#                                    nombre_variable      tipo_sugerido
# 0                                   Marital status         Categórica
# 1                                 Application mode         Categórica
# 2                                Application order         Categórica
# 3                                           Course         Categórica
# 4                       Daytime/evening attendance            Binaria
# 5                           Previous qualification         Categórica
# 6                                      Nacionality         Categórica
# 7                           Mother's qualification  Numérica Discreta
# 8                           Father's qualification  Numérica Discreta
# 9                              Mother's occupation  Numérica Discreta
# 10                             Father's occupation  Numérica Discreta
# 11                                       Displaced            Binaria
# ...

# %%
var_cat = listado_categorias(categorizacion, ['Categórica', 'Binaria'])
var_num = listado_categorias(categorizacion, ['Numérica Discreta', 'Numérica Continua'])

print('Variables categóricas:','\n', var_cat)
print('Variables numéricas:', '\n',var_num)
# Out:
# Variables categóricas:
#  {'Categórica': ['Marital status', 'Application mode', 'Application order', 'Course', 'Previous qualification', 'Nacionality', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP', 'Target'], 'Binaria': ['Daytime/evening attendance', 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'International']}
# Variables numéricas:
# ...

# %%
# Elimino el Target dentro de las variables ya que la vamos a tratar de manera independiente
target = 'Target'
for key,value in var_cat.items():
    if target in value:
        print('Está en "var_cat"')
        var_cat[key].remove(target)
        print(var_cat)
    else:
        for key,value in var_num.items():
            if target in value:
                print('Está en "var_num"')
                var_num[key].remove(target)
                print(var_num)
# Out:
# Está en "var_cat"
# {'Categórica': ['Marital status', 'Application mode', 'Application order', 'Course', 'Previous qualification', 'Nacionality', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP'], 'Binaria': ['Daytime/evening attendance', 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'International']}

# %% [markdown]
# ### Análisis de las **variables categóricas**
#
# Las variables categóricas y binarias están representadas de forma numérica. Sin embargo, ¿qué representan estas cifras?
#
# Investigando por el artículo encontré un repositorio donde explican con gran detalle los datos numéricos de cada variable.
#
# Centrémonos en las variables categóricas y binarias:

# %%
# Lo convierto en una lista para acceder con ella al DF
var_cat = [col for lista in var_cat.values() for col in lista]
var_cat
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Previous qualification',
#  'Nacionality',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (without evaluations)',
#  'Unemployment rate',
#  'Inflation rate',
#  'GDP',
#  'Daytime/evening attendance',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'International']

# %% [markdown]
# **Variables categóricas y binarias**:
#
# |Variable|Descripción|Valores|Observación|
# |--------|-----------|-------|-----------|
# |`Marital status`|Estado civil del estudiante|**1**: *Soltero*; **2**: *Casado*; **3**: *Viudo*; **4**: *Divorciado*; **5**: *Matrimonio de hecho*; **6**: *Legalmente separado*|No tiene un sentido ordinal por lo que la transformaremos a valores tipo `str` para hacer otro tipo de transformación numérica|
# |`Application mode`|Método de aplicación utilizado por el estudiante|**1**: *1ª fase: contingente general*; **2**: *Ordenanza N° 612/93*; **3**: *1ª fase: contingente especial (islas Azores)*; **4**: *Titulares de otros cursos superiores*; **5**: *Ordenanza N° 854-B/99*; **6**: *Estudiante internacional (licenciatura)*; **7**: *1ª fase: contingente especial (isla de Madeira)*; **8**: *2ª fase: contingente general*; **9**: *3ª fase: contingente general*; **10**: *Ordenanza N° 533-A/99, inciso b2 (Plan Diferente)*; **11**: *Ordenanza nº 533-A/99, punto b3 (Otras instituciones)*; **12**: *Mayor de 23 años*; **13**: *Transferir*; **14**: *Cambio de rumbo*; **15**: *Titulados de especialización tecnológica*; **16**: *Cambio de institución/curso*: **17**: *Titulares de diploma de ciclo corto*; **18**: *Cambio de institución/curso (Internacional)*|No tiene un sentido ordinal por lo que la transformaremos a valores tipo `str` para hacer otro tipo de transformación numérica|
# |`Course`|Curso que ha tomado el estudiante|**1**: *Tecnologías de producción de biocombustibles*; **2**: *Animación y diseño multimedia*; **3**: *Servicio Social (asistencia nocturna)*; **4**: *Agronomía*; **5**: *Diseño de comunicación*; **6**: *Enfermería veterinaria*; **7**: *Ingeniería informática*; **8**: *Equinicultura*; **9**: *Gestión*; **10**: *Servicio social*; **11**: *Turismo*; **12**: *Enfermería*; **13**: *Higiene bucal*; **14**: *Gestión de Publicidad y Marketing*; **15**: *Periodismo y comunicación*; **16**: *Educación básica*: **17**: *Gestión (asistencia nocturna)*|No tiene un sentido ordinal por lo que la transformaremos a valores tipo `str` para hacer otro tipo de transformación numérica|
; **28**: *Otro personal de apoyo administrativo*; **29**: *Trabajadores de servicios personales*; **30**: *Vendedores*; **31**: *Trabajadores de cuidado personal y similares*; **32**: *Personal de servicios de protección y seguridad*; **33**: *Agricultores orientados al mercado y trabajadores cualificados de la producción agrícola y ganadera*; **34**: *Agricultores, ganaderos, pescadores, cazadores y recolectores, y personas de subsistencia*; **35**: *Obreros especializados de la construcción y similares, excepto electricistas*; **36**: *Trabajadores cualificados en metalurgia, metalistería y similares*; **37**: *Trabajadores cualificados en electricidad y electrónica*; **38**: *Trabajadores en el procesamiento de alimentos, carpintería, confección y otras industrias y artesanías.*; **39**: *Operadores de plantas y máquinas fijas*; **40**: *Trabajadores de ensamblaje*; **41**: *Conductores de vehículos y operadores de equipos móviles*; **42**: *Trabajadores no cualificados en la agricultura, la producción animal, la pesca y la silvicultura*; **43**: *Trabajadores no cualificados en la industria extractiva, la construcción, la manufactura y el transporte*; **44**: *Asistentes de preparación de comidas*; **45**: *Vendedores ambulantes (excepto de alimentos) y proveedores de servicios ambulantes*|No tendría un orden jerárquico a la hora de codificarlas numéricamente pero sí podemos agruparlas por complejidad profesional, así reduciremos el número de valores|
#
# Hay variables como: `Application order`, `Curricular units 1st sem (credited)`, `Curricular units 1st sem (without evaluations)`, `Curricular units 2nd sem (credited)`, `Curricular units 2nd sem (approved)`, `Curricular units 2nd sem (without evaluations)`, `Unemployment rate`, `Inflation rate` y `GDP` que son datos numéricos realmente pero con muy pocos valores únicos por lo que lo **ELIMINAREMOS** de esta lista y la añadiremos a la lista de variables numéricas.

# %%
trans_inv = ['Marital status', 'Application mode', 'Course', 'Nacionality', 'Gender', "Mother's occupation", "Father's occupation"]
order_trans = ['Previous qualification', "Mother's qualification", "Father's qualification"]

# %% [markdown]
# ### Análisis de las **variables numéricas**

# %%
var_num = [col for lista in var_num.values() for col in lista]
var_num
# Out:
# ["Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Age at enrollment',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)']

# %%
# Añado las variables numéricas que descubrimos en las variables categóricas y las elimino de la lista de categóricas
lista_append = ['Application order', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']

for col in lista_append:
    var_num.append(col)
    var_cat.remove(col)

print(var_num)
print(var_cat)
# Out:
# ["Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Age at enrollment', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Application order', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']
# ['Marital status', 'Application mode', 'Course', 'Previous qualification', 'Nacionality', 'Daytime/evening attendance', 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'International']

# %%
# Compruebo que no me he dejado ninguna variable por analizar
print(len(var_cat) + len(var_num)) # No contiene el Target por lo que va a tener uno menos
print(len(df.columns))
# Out:
# 34
# 35

# %% [markdown]
# **Variables numéricas**:
# |Variable|Descripción|
# |--------|-----------|
# |`Age at enrollment`|Edad del estudiante al momento de la inscripción|
# |`Curricular units 1st/2nd sem (credited)`|Número de unidades curriculares acreditadas por el estudiante en el primer semestre/segundo semestre|
# |`Curricular units 1st/2nd sem (enrolled)`|Número de unidades curriculares matriculadas por el estudiante en el primer semestre/segundo semestre|
# |`Curricular units 1st/2nd sem (evaluations)`|Número de unidades curriculares evaluadas por el estudiante en el primer semestre/segundo semestre|
# |`Curricular units 1st/2nd sem (approved)`|Número de unidades curriculares aprovadas por el estudiante en el primer semestre/segundo semestre|
# |`Curricular units 1st/2nd sem (without evaluations)`|Número de unidades curriculares sin evaluar por el estudiante en el primer semestre/segundo semestre|
# |`Curricular units 1st/2nd sem (grade)`|Calificación obtenida en las unidades curriculares del primer semestre/segundo semestre|
# |`Application order`|Orden en el que el estudiante presentó la solicitud|
# |`Unemployment rate`|Tasa de desempleo del país en el cual vive el estudiante|
# |`Inflation rate`|Tasa de inflación del país en el cual vive el estudiante|
# |`GDP`|PIB del país en el cual vive el estudiante|
#
# En esta lista de variables numéricas también se han añadido variables categóricas ya que sus componentes únicos superan los 21 (puesto como filtro en la función) por lo que lo añadiremos en la tabla de variables categóricas como: `Mother's qualification`, `Father's qualification`, `Mother's occupation`, `Father's occupation`

# %%
lista_append = ["Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"]

for col in lista_append:
    var_num.remove(col)
    var_cat.append(col)

print(var_num)
print(var_cat)
# Out:
# ['Age at enrollment', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Application order', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']
# ['Marital status', 'Application mode', 'Course', 'Previous qualification', 'Nacionality', 'Daytime/evening attendance', 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'International', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"]

# %%
# Vuelvo a comprobar
print(len(var_cat) + len(var_num)) # No contiene el Target por lo que va a tener uno menos
print(len(df.columns))
# Out:
# 34
# 35

# %% [markdown]
# ## Tratamiento de las **variables categóricas**
# ### Transformación a la inversa
# Para poder realizar mejor los análisis de las variables junto con el **Target**, se realizará una transformación a la inversa mapeando todos los valores de las variables categóricas.

# %%
trans_inv
# Out:
# ['Marital status',
#  'Application mode',
#  'Course',
#  'Nacionality',
#  'Gender',
#  "Mother's occupation",
#  "Father's occupation"]

# %%
# Variable que correspnde con el nombre del archivo (que quiero conseguir) con su correspondiente columna del DF
archivos_columnas = {
                     'marital_status': 'Marital status',
                     'nationality': 'Nacionality',
                     'application_mode': 'Application mode',
                     'course_names': 'Course',
                     'parent_occupation': ["Mother's occupation", "Father's occupation"],
                     'previous_quals': 'Previous qualification',
                     'parent_previous_quals': ["Mother's qualification", "Father's qualification"],
                     'gender': 'Gender'}

# %%
ROOT_PATH = './data/raw/var_cod/'

#dict_cod = generar_mapeos(ROOT_PATH, archivos_columnas)

# %%
df_mapeo = mapear(df, ROOT_PATH, archivos_columnas)

# %%
df_mapeo.head()
# Out:
#   Marital status                  Application mode  Application order  \
# 0         Single      2nd phase—general contingent                  5
# 1         Single  International student (bachelor)                  1
# 2         Single      1st phase—general contingent                  5
# 3         Single      2nd phase—general contingent                  2
# 4        Married                 Over 23 years old                  1
#
#                                 Course  Daytime/evening attendance  \
# 0      Animation and Multimedia Design                           1
# 1                              Tourism                           1
# 2                 Communication Design                           1
# 3         Journalism and Communication                           1
# 4  Social Service (evening attendance)                           0
#
#   Previous qualification Nacionality  \
# 0    Secondary education  Portuguese
# 1    Secondary education  Portuguese
# ...

# %% [markdown]
# Lo guardo en un archivo `.csv` y todo lo que transforme de ahí será a partir del set de entrenamiento

# %%
ruta = './data/processed/dataset_mapeado.csv'
df_mapeo.to_csv(ruta, index=False)
